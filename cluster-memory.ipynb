# %%
from ipywidgets import Layout, Button, Box, ToggleButtons
from ipywidgets import interact, interactive, fixed, interact_manual
from ipywidgets import HBox, VBox, Label, IntSlider
import ipywidgets as widgets
#import ipywidgets as widgets

from IPython.display import display
from IPython.display import Image
from IPython.core.display import HTML
#Html way for posting local images;however, widget images update automatically/without refreshing (so cooler)
#PATH = "python_games/"
#Image(filename = PATH + "hollowsphere.png", width=200, height=200)
#Image("hollowsphere.png", width=200, height=200)

from subprocess import *
from __future__ import print_function

#Global y instantiation because instatiation doesn't occur in a function
y = "Slow"

#instatiating rgb color variables of the shape
#python input questions were cancelled because 
#r1 = input("What is the red value? ")
#g1 = input("What is the green value? ")
#b1 = input("What is the blue value? ")
#a1 = input("What is the transparent value? ")
r1 = 255
g1 = 0
b1 = 0
a1 = 255

#instatiating rgb to openscad 0-1 scale conversion variables
rvalue = (int(r1)/255)*1
gvalue = (int(g1)/255)*1
bvalue = (int(b1)/255)*1
avalue = (int(a1)/255)*1

#instantiating cube dimensions variables
#wvalue = input("What is the width value? ")
#hvalue = input("What is the height value? ")
#dvalue = input("What is the depth value? ")
wvalue = 20
hvalue = 20
dvalue = 20

#instantiating shape transformation/relocation variables
xvalue = 0
yvalue = 0
zvalue = 0

#Instatiating sphere dimension variables
radvalue = 15

#defines funciton that makes global y equal to the widget value x while being interacted with
def reflect(x):
    global y
    print(x)
    y = x
    print("y is: " + y)
    if y == "Fast":
        picdraw()
    if y == "Regular":
        picdraw()

#displays the updatable image, requires conditional to update, so far (reoccurring scripting didn't work, ex while loop)
def picdraw():
    print ("hooray")
    disfile = open("hollowsphere.png", "rb")
    image = disfile.read()
    picta = widgets.Image(
    value=image,
    format='png',
    width=300,
    height=400)
    #display.display(display.Image(os.path.join("pi", "hollowsphere.png")))
    display(picta)

#defines function that appends 
def proscene(y):
    #w, writes/overwrites and a, appends
    #file = open('cubez.scad','w') 
    file = open('cubez.scad','w') 

    #contents/openscad commands written to the file
    #file.write('translate( v = [10, 10, 10] ) {\n')
    file.write('translate( v = ['+str(xvalue)+', '+str(yvalue)+', '+str(zvalue)+'] ) {\n')
    file.write('color( c = ['+str(rvalue)+', '+str(gvalue)+', '+str(bvalue)+', '+str(avalue)+'] ) {\n') 
    file.write('cube(['+str(wvalue)+','+str(hvalue)+','+str(dvalue)+'],center=true);\n')
    file.write('}\n')
    file.write('}\n')
    file.write('sphere(r = '+str(radvalue)+');\n')
    file.close() 
    
    #--camera=translatex,y,z,rotx,y,z,dist
    #subprocess start command for commands you enter into terminal
    #cam1 = Popen(['sudo /usr/bin/openscad -o hollowsphere.png cubez.scad  --camera=0,0,0,'+str(y)+',0,0,1000 --projection=p --imgsize=800,800'], shell=True, stdin=PIPE, stdout=PIPE)
    cam1 = Popen(['sudo /usr/bin/openscad -o hollowsphere.png cubez.scad  --camera=0,0,0,0,0,0,1000 --projection=p --imgsize=800,800'], shell=True, stdin=PIPE, stdout=PIPE)

    #subprocess check close command
    #while cam1.poll() is None:
    #    l = cam1.stdout.readline()
        # print (l)
    
#defining functions that are slider controlled for shape rgb color values tested
def redpar(x):
    return x

def bluepar(x):
    return x

def greenpar(x):
    if x < 100:
        print("Adjustable: "+ str(x))
        proscene(x)
        picdraw()
    if x == 100:
        print("Max: "+ str(x))
        proscene(x)
        picdraw()
        
def f(a, b, c, d, e):
    print (d)
    print(a + b)
    print (c)
    print (e)
    #return a+b
    #display(c)
    #return c

#instantiating interactives so that they can be stored in a container/visual dashboard
w = interactive(f, a=10, b=20, c=False, d=IntSlider(min=0,max=255,step=1,value=0), e = ToggleButtons(
    options=['Slow', 'Regular', 'Fast'],
    description='Speed:',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=['Description of slow', 'Description of regular', 'Description of fast'],
#     icons=['check'] * 3
))

w2 = interactive(f, a=20, b=30, c=False, d=IntSlider(min=0,max=255,step=1,value=0), e = ToggleButtons(
    options=['Slow', 'Regular', 'Fast'],
    description='Speed:',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=['Description of slow', 'Description of regular', 'Description of fast'],
#     icons=['check'] * 3
))

#instatiating containers
box = HBox([w, w2, w])
stack = VBox([box, box])
    
#sliders that control shapes rgb color values
interact(redpar, x=widgets.IntSlider(min=0,max=255,step=1,value=0));
interact(bluepar, x=widgets.IntSlider(min=0,max=255,step=1,value=0));
interact(greenpar, x=widgets.IntSlider(min=0,max=100,step=1,value=0));

#Buttons
#Togglebuttons was used instead because it was imported by name
#as opposed to 'as widgets' or 'widgets.*"
#widgets.Togglebuttons()
interact(reflect, x = ToggleButtons(
    options=['Slow', 'Regular', 'Fast'],
    description='Speed:',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=['Description of slow', 'Description of regular', 'Description of fast'],
#   icons=['check'] * 3
)
);

#display containers
box
stack

#display of an interactive
#display(w)

#widgets referred as the widgets.* without importing by type name
#widgets.BoundedFloatText(
#    value=7.5,
#    min=0,
#    max=10.0,
#    step=0.1,
#    description='Text:',
#    disabled=False
#)

#widgets.Dropdown(
#    options=['1', '2', '3'],
#    value='2',
#    description='Number:',
#    disabled=False,
#)

# %%
quad = 0
print (quad)

def quadmaker():
    global quad
    quad = 4
    print (quad)

print(quad)
quadmaker()
print(quad)
# Out:
# 0
# 0
# 4
# 4

# %%
from ipywidgets import Layout, Button, Box, ToggleButtons, BoundedFloatText
from ipywidgets import interact, interactive, fixed, interact_manual
from ipywidgets import HBox, VBox, Label, IntSlider
import ipywidgets as widgets
#import ipywidgets as widgets

from IPython.display import display
from IPython.display import Image
from IPython.core.display import HTML

from IPython.display import clear_output

#Html way for posting local images;however, widget images update automatically/without refreshing (so cooler)
#PATH = "python_games/"
#Image(filename = PATH + "hollowsphere.png", width=200, height=200)
#Image("hollowsphere.png", width=200, height=200)

from subprocess import *
from __future__ import print_function

generalnumber = 1
specificnumber = 1
certainnumber = 1

def displaytextgeneral(inputtextgeneral):
    global generalnumber
    print ("Old General Number/Xvalue: " + str(generalnumber))
    print ("Hello: " + str(inputtextgeneral))
    generalnumber = inputtextgeneral
    print ("New General Number: " + str(generalnumber))
    
    #proscene()
    
def displaytextspecific(inputtextspecific):
    global specificnumber
    print ("Old Specific Number/Yvalue: " + str(specificnumber))
    print ("Hello: " + str(inputtextspecific))
    specificnumber = inputtextspecific
    print ("New specific Number: " + str(specificnumber))
    
    #proscene()
    
def displaytextcertain(inputtextcertain):
    global certainnumber
    print ("Old Certain Number/Zvalue: " + str(certainnumber))
    print ("Hello: " + str(inputtextcertain))
    certainnumber = inputtextcertain
    print ("New certain Number: " + str(certainnumber))
    
    #proscene()

#defines function that appends 
def proscene(x):
    global generalnumber
    global specificnumber
    global certainnumber
    xvalue = generalnumber
    yvalue = specificnumber
    zvalue = certainnumber
    rvalue = 0.5
    gvalue = 0.5
    bvalue = 0.5
    avalue = 0.5
    wvalue = 10
    hvalue = 10
    dvalue = 10
    radvalue = 0.5
    #w, writes/overwrites and a, appends
    #file = open('cubez.scad','w') 
    file = open('cubez.scad','w') 
    #contents/openscad commands written to the file
    #file.write('translate( v = [10, 10, 10] ) {\n')
    file.write('translate( v = ['+str(xvalue)+', '+str(yvalue)+', '+str(zvalue)+'] ) {\n')
    file.write('color( c = ['+str(rvalue)+', '+str(gvalue)+', '+str(bvalue)+', '+str(avalue)+'] ) {\n') 
    file.write('cube(['+str(wvalue)+','+str(hvalue)+','+str(dvalue)+'],center=true);\n')
    file.write('}\n')
    file.write('}\n')
    file.write('sphere(r = '+str(radvalue)+');\n')
    file.close() 
    
    #--camera=translatex,y,z,rotx,y,z,dist
    #subprocess start command for commands you enter into terminal
    #cam1 = Popen(['sudo /usr/bin/openscad -o hollowsphere.png cubez.scad  --camera=0,0,0,'+str(y)+',0,0,1000 --projection=p --imgsize=800,800'], shell=True, stdin=PIPE, stdout=PIPE)
    cam1 = Popen(['sudo /usr/bin/openscad -o hollowsphere.png cubez.scad  --camera=0,0,0,0,0,0,1000 --projection=p --imgsize=800,800'], shell=True, stdin=PIPE, stdout=PIPE)

    #subprocess check close command
    #while cam1.poll() is None:
    #    l = cam1.stdout.readline()
        # print (l)
        
    #print ("uploading file...")
    disfile = open("hollowsphere.png", "rb")
    image = disfile.read()
    picta = widgets.Image(
    value=image,
    format='png',
    width=300,
    height=400)
    #display.display(display.Image(os.path.join("pi", "hollowsphere.png")))
    display(picta)
    #picta
    
#instantiating interactives so that they can be stored in a container/visual dashboard
inputtextboxgeneral = interactive(displaytextgeneral, inputtextgeneral = BoundedFloatText(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='X:',
    disabled=False
))

#instantiating interactives so that they can be stored in a container/visual dashboard
inputtextboxspecific = interactive(displaytextspecific, inputtextspecific = BoundedFloatText(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Y:',
    disabled=False
))

#instantiating interactives so that they can be stored in a container/visual dashboard
inputtextboxcertain = interactive(displaytextcertain, inputtextcertain = BoundedFloatText(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Z:',
    disabled=False
))


renderbutton = interactive(proscene, x = ToggleButtons(
    options=['Render','off'],
    description='Update:',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=['Rendering Image', 'off'],
   icons=['check']
))

#button = widgets.Button(description="Click Me!")
#display(button)

#button.on_click(proscene)

#instatiating containers
#HBox = horizontal box
#VBox = vertical box
boxcentertranslate = HBox([inputtextboxgeneral, inputtextboxspecific, inputtextboxcertain])
#stack = VBox([boxcentertranslate, renderbutton])
stack = VBox([boxcentertranslate, renderbutton])

#widgets referred as the widgets.* without importing by type name
#widgets.BoundedFloatText(
#    value=7.5,
#    min=0,
#    max=10.0,
#    step=0.1,
#    description='Text:',
#    disabled=False
#)


stack
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/ipywidgets/widgets/interaction.py in update(self, *args)
#     249                     value = widget.get_interact_value()
#     250                     self.kwargs[widget._kwarg] = value
# --> 251                 self.result = self.f(**self.kwargs)
#     252                 show_inline_matplotlib_plots()
#     253                 if self.auto_display and self.result is not None:
#
# <ipython-input-10-697ed8c1867c> in proscene(x)
#      90
#      91     #print ("uploading file...")
# ---> 92     disfile = open("hollowsphere.png", "rb")
#      93     image = disfile.read()
#      94     picta = widgets.Image(
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hollowsphere.png'

# %%
def shapelibraryappend(): 
    xvalue = 0
    yvalue = 0
    zvalue = 0
    rvalue = 0.5
    gvalue = 0.5
    bvalue = 0.5
    avalue = 0.5
    wvalue = 10
    hvalue = 10
    dvalue = 10
    radvalue = 0.5
    #w, writes/overwrites and a, appends
    #file = open('cubez.scad','w') 
    
    file = open('world.scad','a') 
    #contents/openscad commands written to the file
    #file.write('translate( v = [10, 10, 10] ) {\n')
    file.write('translate( v = ['+str(xvalue)+', '+str(yvalue)+', '+str(zvalue)+'] ) {\n')
    file.write('color( c = ['+str(rvalue)+', '+str(gvalue)+', '+str(bvalue)+', '+str(avalue)+'] ) {\n') 
    file.write('cube(['+str(wvalue)+','+str(hvalue)+','+str(dvalue)+'],center=true);\n')
    file.write('}\n')
    file.write('}\n')
    file.write('sphere(r = '+str(radvalue)+');\n')
    file.close()
    
shapelibraryappend()

# %%
my_file = open("world.scad","r")
docread = my_file.read()
my_file.close()

register = 0
lock = 0

def number(setnumber):
    hs = open("library.scad","a")
    hs.write(setnumber)
    hs.close()
    

def sign(setsign):
    hs = open("library.scad","a")
    hs.write(setsign)
    hs.close() 
    
def cube():
    hs = open("library.scad","a")
    hs.write("cube \n")
    hs.close()
    
def color():
    hs = open("library.scad","a")
    hs.write("color \n")
    hs.close()
    
def translate():
    hs = open("library.scad","a")
    hs.write("translated shape \n")
    hs.close()

list_word = {"color":color,"translate":translate,"cube":cube}    

#in_dict = 0
for target in docread:
    if target !=" ":
        lock += 1
    else:
        if docread[register-lock:register].isalpha():
            print (target)
            print (docread[register-lock:register])
            for ftarget in list_word:
                if ftarget == docread[register-lock:register]:
                    print ("True")
                    list_word[docread[register-lock:register]]()
                else:
                    #in_dict += 1
                    print ("False")
            #if in_dict == len(list_word):
                #sign(docread[register-lock:register])
                #in_dict = 0
            lock = 0
            #in_dict = 0
        elif docread[register-lock:register].isalnum():
            print (target)
            print ("number: " + docread[register-lock:register])
            number(docread[register-lock:register])
            lock = 0
        #else:
        #    print (target)
        #    print ("something else: " + docread[register-lock:register])
        #    sign(docread[register-lock:register])
        #    lock = 0
    register += 1

# %%
print(len(list_word))
# Out:
# 3

# %%
from collections import Counter

data = '''\
ashwin programmer india
amith programmer india'''

c = Counter()
for line in data.splitlines():
    c.update(line.split())
print(c)
# Out:
# Counter({'india': 2, 'programmer': 2, 'ashwin': 1, 'amith': 1})

# %%
from ipywidgets import Layout, Button, Box, ToggleButtons, Dropdown
colorenable = 0
shapes=['1', '2', '3','4']
for target in docread:
    if target == "c":
        colorenable = 1
    if colorenable == 1:
        if target == "o":
            print ("color")
            shapes.extend(["color"])
        if target == "u":
            print ("cube")
            shapes.extend(["cube"])
print (shapes)  

box = Dropdown(options=shapes,value='1',description='Number:',disabled=False)
box
# Out:
# color
# color
# cube
# cube
# ['1', '2', '3', '4', 'color', 'color', 'cube', 'cube']
# Dropdown(description='Number:', options=('1', '2', '3', '4', 'color', 'color', 'cube', 'cube'), value='1')

# %%
stars = ['1', '2', '3','4']

box = widgets.Dropdown(
    options=stars,
    value='2',
    description='Number:',
    disabled=False,
)

box
# Out:
# Dropdown(description='Number:', index=1, options=('1', '2', '3', '4'), value='2')
