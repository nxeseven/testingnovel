# %% [markdown]
# # Speech Application

# %% [markdown]
# *This application creates an audio file generating vocaloid.*

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# [Update OS](#update_os)
#
# [Upgrade OS](#upgrade_os)
#
# [Perform Reboot](#reboot)
#
# Link to [Landing](landing.ipynb)
#
# [Adafruit Raspberry Pi Blog](https://blog.adafruit.com/category/raspberry-pi/)

# %% [markdown]
# <a id='update_os'></a>
#
#
# ### Update OS

# %%
# !sudo apt-get update -y
# Out:
# Get:1 http://security.debian.org jessie/updates InRelease [63.1 kB]
# Ign http://ftp.debian.org jessie InRelease
# Hit http://archive.raspberrypi.org jessie InRelease
# Hit http://security.debian.org jessie/updates/main i386 Packages
# Hit http://ftp.debian.org jessie-updates InRelease
# Hit http://security.debian.org jessie/updates/contrib i386 Packages
# Hit http://ftp.debian.org jessie Release.gpg
# Hit http://security.debian.org jessie/updates/non-free i386 Packages
# Hit http://security.debian.org jessie/updates/contrib Translation-en
# Hit http://archive.raspberrypi.org jessie/main i386 Packages
# Hit http://ftp.debian.org jessie-updates/main i386 Packages
# Hit http://security.debian.org jessie/updates/main Translation-en
# Hit http://security.debian.org jessie/updates/non-free Translation-en
# Hit http://ftp.debian.org jessie-updates/contrib i386 Packages
# Hit http://archive.raspberrypi.org jessie/ui i386 Packages
# ...

# %% [markdown]
# <a id='upgrade_os'></a>
#
#
# ### Upgrade OS
# *Requires reboot*

# %%
# !sudo apt-get dist-upgrade -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages will be upgraded:
#   libssl1.0.0 openssl
# 2 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Need to get 2,815 kB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 http://security.debian.org/ jessie/updates/main libssl1.0.0 i386 1.0.1t-1+deb8u7 [2,141 kB]
# Get:2 http://security.debian.org/ jessie/updates/main openssl i386 1.0.1t-1+deb8u7 [673 kB]
# Fetched 2,815 kB in 6s (460 kB/s)
# Reading changelogs... Done
# Preconfiguring packages ...
# (Reading database ... 114703 files and directories currently installed.)
# Preparing to unpack .../libssl1.0.0_1.0.1t-1+deb8u7_i386.deb ...
# Unpacking libssl1.0.0:i386 (1.0.1t-1+deb8u7) over (1.0.1t-1+deb8u6) ...
# Preparing to unpack .../openssl_1.0.1t-1+deb8u7_i386.deb ...
# Unpacking openssl (1.0.1t-1+deb8u7) over (1.0.1t-1+deb8u6) ...
# ...

# %% [markdown]
# <a id='reboot'></a>
#
#
# ### Perform Reboot
# *warning: make sure to turn off jupyter notebook server*

# %%
# !sudo reboot

# %% [markdown]
# ### Install Espeak Text-to-Speech software

# %%
# !sudo apt-get install espeak -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following extra packages will be installed:
#   espeak-data libespeak1 libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak1 libportaudio2 libsonic0
# 0 upgraded, 5 newly installed, 0 to remove and 2 not upgraded.
# Need to get 1,245 kB of archives.
# After this operation, 2,945 kB of additional disk space will be used.
# Get:1 http://ftp.debian.org/debian/ jessie/main libportaudio2 i386 19+svn20140130-1 [63.1 kB]
# Get:2 http://ftp.debian.org/debian/ jessie/main libsonic0 i386 0.1.17-1.1 [14.4 kB]
# Get:3 http://ftp.debian.org/debian/ jessie/main espeak-data i386 1.48.04+dfsg-1 [943 kB]
# Get:4 http://ftp.debian.org/debian/ jessie/main libespeak1 i386 1.48.04+dfsg-1 [154 kB]
# Get:5 http://ftp.debian.org/debian/ jessie/main espeak i386 1.48.04+dfsg-1 [70.9 kB]
# Fetched 1,245 kB in 5s (226 kB/s)
# ...

# %% [markdown]
# ### Espeak Speak Command

# %%
# !espeak "This. Is. Speech. Synthesis."
# Out:
# ALSA lib pcm.c:2239:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2239:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2239:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# ALSA lib pcm.c:2239:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.surround71
# ALSA lib setup.c:548:(add_elem) Cannot obtain info for CTL elem (MIXER,'IEC958 Playback Default',0,0,0): No such file or directory
# ALSA lib setup.c:548:(add_elem) Cannot obtain info for CTL elem (MIXER,'IEC958 Playback Default',0,0,0): No such file or directory
# ALSA lib setup.c:548:(add_elem) Cannot obtain info for CTL elem (MIXER,'IEC958 Playback Default',0,0,0): No such file or directory
# ALSA lib pcm.c:2239:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.hdmi
# ALSA lib pcm.c:2239:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.hdmi
# ALSA lib pcm.c:2239:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.modem
# ALSA lib pcm.c:2239:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.modem
# ...

# %% [markdown]
# ### Python Using an OS.System command

# %%
import os
from time import sleep

#receive greeting message from scripted robot
os.system("sudo espeak \"hello from your robot friend\"")
# Out:
# 0

# %% [markdown]
# ### Espeak Audio file write
# Write a wav audio file of the text-to-speech

# %%
# !espeak "This. Is. Speech. Synthesis. I. Hope. You. Enjoy." -w speechsynth.wav

# %% [markdown]
# ### Install Sox
# Install Sox, the swiss army knife of audio manipulation

# %%
# !sudo apt-get install sox -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# sox is already the newest version.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %% [markdown]
# ### Sox Create Spectrogram Image from Audio File

# %%
# !sox speechsynth.wav -n spectrogram -o spectrum.png

# %% [markdown]
# ### List Contents

# %%
# !ls
# Out:
# delayed.wav  Downloads	neural.py.save	python_games  speechapp.ipynb  Videos
# Desktop      Music	Pictures	sigmoid.py    speechsynth.wav
# Documents    neural.py	Public		spectrum.png  Templates

# %% [markdown]
# ### Display the Spectrogram Image

# %% [markdown]
# ![title](spectrum.png)

# %% [markdown]
# ### Sox Play Audio File

# %%
# !play speechsynth.wav
# Out:
# speechsynth.wav:
#
#  File Size: 127k      Bit Rate: 353k
#   Encoding: Signed PCM
#   Channels: 1 @ 16-bit
# Samplerate: 22050Hz
# Replaygain: off
#   Duration: 00:00:02.89
#
# In:100%  00:00:02.89 [00:00:00.00] Out:139k  [      |      ] Hd:4.1 Clip:0
# Done.

# %%
import IPython.display as ipd
ipd.Audio('speechsynth.wav') # load a local WAV file
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Sox Play Two Synth Tones for 3 Seconds

# %%
# !play -n synth 3 sin 347 sin 357
# Out:
#   Encoding: n/a
#   Channels: 2 @ 32-bit
# Samplerate: 48000Hz
# Replaygain: off
#   Duration: unknown
#
# In:0.00% 00:00:00.00 [00:00:00.00] Out:0     [      |      ]        Clip:0    play WARN alsa: under-run
# In:0.00% 00:00:03.07 [00:00:00.00] Out:144k  [!=====|=====!] Hd:0.0 Clip:0
# Done.

# %% [markdown]
# ### Sox Play Synth Tones by key

# %%
# !play -n synth 4 pluck B3 pluck E4 pluck D3
# Out:
#   Encoding: n/a
#   Channels: 3 @ 32-bit
# Samplerate: 48000Hz
# Replaygain: off
#   Duration: unknown
#
# In:0.00% 00:00:04.04 [00:00:00.00] Out:192k  [      |      ]        Clip:0
# Done.

# %% [markdown]
# ### Post Youtube

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('5z3MVEc33FI')

# %% [markdown]
# ### Post iFrame Youtube and Vimeo Embedded Link

# %%
from IPython.display import HTML

# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/S_f2qV2_U00?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>')

# Vimeo
#HTML('<iframe src="https://player.vimeo.com/video/26763844?title=0&byline=0&portrait=0" width="700" height="394" frameborder="0" webkitallowfullscreen mozallowfullscreen allowfullscreen></iframe><p><a href="https://vimeo.com/26763844">BAXTER DURY - CLAIRE (Dir Cut)</a> from <a href="https://vimeo.com/dannysangra">Danny Sangra</a> on <a href="https://vimeo.com">Vimeo</a>.</p>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/S_f2qV2_U00?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>

# %%
# !sudo apt-get install imagemagick -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following extra packages will be installed:
#   ghostscript imagemagick-6.q16 imagemagick-common libdjvulibre-text
#   libdjvulibre21 libgs9 libgs9-common libijs-0.35 libjbig2dec0 liblqr-1-0
#   libmagickcore-6.q16-2 libmagickcore-6.q16-2-extra libmagickwand-6.q16-2
#   libnetpbm10 libpaper-utils libpaper1 libwmf0.2-7 netpbm
# Suggested packages:
#   ghostscript-x imagemagick-doc autotrace enscript ffmpeg gimp gnuplot grads
#   graphviz hp2xx html2ps libwmf-bin mplayer povray radiance sane-utils
#   texlive-base-bin transfig ufraw-batch inkscape
# The following NEW packages will be installed:
#   ghostscript imagemagick imagemagick-6.q16 imagemagick-common
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-2 libmagickcore-6.q16-2-extra
#   libmagickwand-6.q16-2 libnetpbm10 libpaper-utils libpaper1 libwmf0.2-7
#   netpbm
# ...

# %%
# !sudo apt-get -y install libav-tools -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following extra packages will be installed:
#   libavdevice55 libavfilter5
# Suggested packages:
#   frei0r-plugins
# The following NEW packages will be installed:
#   libav-tools libavdevice55 libavfilter5
# 0 upgraded, 3 newly installed, 0 to remove and 0 not upgraded.
# Need to get 839 kB of archives.
# After this operation, 3,856 kB of additional disk space will be used.
# Get:1 http://security.debian.org/ jessie/updates/main libavdevice55 i386 6:11.11-1~deb8u1 [106 kB]
# Get:2 http://security.debian.org/ jessie/updates/main libavfilter5 i386 6:11.11-1~deb8u1 [255 kB]
# Get:3 http://security.debian.org/ jessie/updates/main libav-tools i386 6:11.11-1~deb8u1 [478 kB]
# Fetched 839 kB in 1s (623 kB/s)
# Selecting previously unselected package libavdevice55:i386.
# (Reading database ... 116062 files and directories currently installed.)
# ...

# %%
# !sudo apt-get install mplayer -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'mplayer2' instead of 'mplayer'
# The following extra packages will be installed:
#   liba52-0.7.4 libbs2b0 liblircclient0 liblua5.2-0 libpostproc52
#   libquvi-scripts libquvi7
# Suggested packages:
#   lirc
# The following NEW packages will be installed:
#   liba52-0.7.4 libbs2b0 liblircclient0 liblua5.2-0 libpostproc52
#   libquvi-scripts libquvi7 mplayer2
# 0 upgraded, 8 newly installed, 0 to remove and 0 not upgraded.
# Need to get 1,307 kB of archives.
# After this operation, 3,573 kB of additional disk space will be used.
# Get:1 http://ftp.debian.org/debian/ jessie/main liblua5.2-0 i386 5.2.3-1.1 [92.0 kB]
# Get:2 http://ftp.debian.org/debian/ jessie/main libquvi-scripts all 0.4.21-2 [37.3 kB]
# Get:3 http://ftp.debian.org/debian/ jessie/main libquvi7 i386 0.4.1-3 [22.2 kB]
# Get:4 http://ftp.debian.org/debian/ jessie/main liba52-0.7.4 i386 0.7.4-17 [28.9 kB]
# ...

# %%
import os
from time import sleep


#imagemagick draw a rectangle on a series of jpg's
os.system("convert -size 800x800 xc:skyblue -fill white -stroke black -draw \"rectangle 20,10 80,50\" draw01.jpg")
os.system("convert -size 800x800 xc:skyblue -fill white -stroke black -draw \"rectangle 30,20 90,60\" draw02.jpg")
os.system("convert -size 800x800 xc:skyblue -fill white -stroke black -draw \"rectangle 40,30 100,70\" draw03.jpg")
os.system("convert -size 800x800 xc:skyblue -fill white -stroke black -draw \"rectangle 50,40 110,80\" draw04.jpg")


#convert image sequence into an mp4
os.system("avconv -r 10 -i draw0%d.jpg -r 10 -vcodec libx264 -crf 20 -g 15 timelapse.mp4 -y")

#play video
os.system("sudo mplayer timelapse.mp4")
# Out:
# 0

# %%
import io
import base64
from IPython.display import HTML

video = io.open('timelapse.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# !sudo apt-get install youtube-dl -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following extra packages will be installed:
#   rtmpdump
# The following NEW packages will be installed:
#   rtmpdump youtube-dl
# 0 upgraded, 2 newly installed, 0 to remove and 0 not upgraded.
# Need to get 372 kB of archives.
# After this operation, 1,626 kB of additional disk space will be used.
# Get:1 http://ftp.debian.org/debian/ jessie/main rtmpdump i386 2.4+20150115.gita107cef-1+deb8u1 [49.7 kB]
# Get:2 http://ftp.debian.org/debian/ jessie/main youtube-dl all 2014.08.05-1+deb8u1 [323 kB]
# Fetched 372 kB in 2s (153 kB/s)
# Selecting previously unselected package rtmpdump.
# (Reading database ... 116279 files and directories currently installed.)
# Preparing to unpack .../rtmpdump_2.4+20150115.gita107cef-1+deb8u1_i386.deb ...
# Unpacking rtmpdump (2.4+20150115.gita107cef-1+deb8u1) ...
# Selecting previously unselected package youtube-dl.
# ...

# %%
import os
from time import sleep

#download nes walkthrough
os.system("youtube-dl -f 18 https://www.youtube.com/watch?v=RvYPsa1Pbrs")

#trim the first 10 seconds of the video
os.system("avconv -i Clash\ At\ Demonhead\ NES\ 1_9\!\!\!-RvYPsa1Pbrs.mp4 -ss 0.0 -t 10.0 -codec copy intro.mp4")

#play the video
os.system("sudo mplayer intro.mp4")
# Out:
# 0

# %%
# !sudo mplayer timelapse.mp4
# Out:
# MPlayer2 2.0-728-g2c378c7-4+b1 (C) 2000-2012 MPlayer Team
# Cannot open file '/root/.mplayer/input.conf': No such file or directory
# Failed to open /root/.mplayer/input.conf.
# Cannot open file '/etc/mplayer/input.conf': No such file or directory
# Failed to open /etc/mplayer/input.conf.
#
# Playing timelapse.mp4.
# Detected file format: QuickTime / MOV (libavformat)
# [lavf] stream 0: video (h264), -vid 0
# Clip info:
#  major_brand: isom
#  minor_version: 512
#  compatible_brands: isomiso2avc1mp41
#  encoder: Lavf56.1.0
# Load subtitles in .
# Failed to open VDPAU backend libvdpau_nvidia.so: cannot open shared object file: No such file or directory
# [vdpau] Error when calling vdp_device_create_x11: 1
# [VO_XV] It seems there is no Xvideo support for your video card available.
# [VO_XV] Run 'xvinfo' to verify its Xv support and read
# [VO_XV] DOCS/HTML/en/video.html#xv!
# [VO_XV] See 'mplayer -vo help' for other (non-xv) video out drivers.
# [VO_XV] Try -vo x11.
# [ass] auto-open
# ...

# %%
import io
import base64
from IPython.display import HTML

video = io.open('intro.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
